# %% [markdown]
# # CS 6010 Data Science Programming - Project 2
# ## Graph Analysis and Network Communities
#
# This notebook provides an interactive exploration of graph analysis techniques and comparative analysis between two graphs.
#
# ### Key Objectives:
# 1. Analyze graph properties (density, triangles, connected components, diameter, reciprocity)
# 2. Compare two different graphs
# 3. Visualize graph structures and properties
# 4. Generate insights and conclusions

# %%
# Import necessary libraries
import sys
import os
sys.path.append('../src')

import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from graph_analysis import GraphAnalyzer, GraphComparator
from data_loader import GraphDataLoader
from visualization import GraphVisualizer

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# %matplotlib inline
